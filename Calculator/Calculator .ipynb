# %%
import time

def calculator():
    operations = {
        '1' : "Addition",
        '2' : "Subtraction",
        '3' : "Multiplication",
        '4' : "Divison",
        '5' : "Exit"
    }
    while True:
        print("Select Operation")
        for key, value in operations.items():
            print(f"{key}.{value}")
            
        choice = input("Enter choice (1 to 5) : ")
        
        if choice in operations:
            if choice == '5':
                print("Exiting the calculator")
                break
                
            num1 = int(input("Enter the First number :"))
            print("You entered First number:", num1)
            num2 = int(input("Enter the Second number :"))
            print("You entered Second number:", num2)
            
            if choice == '1':
                result = num1 + num2
            elif choice == '2':
                result = num1 - num2
            elif choice == '3':
                result = num1 * num2
            elif choice == '4':
                if num2 !=0:
                    result = num1 / num2
                else:
                    result = "Error! You can't Division by zero"
                    
            print(f"The result of {operations[choice]} is: {result}")
            print("------------------------------------------------")
            time.sleep(2)
        else:
            print("Invalid Input. Please select a valid Operation.")

calculator()
# Out:
# Select Operation
# 1.Addition
# 2.Subtraction
# 3.Multiplication
# 4.Divison
# 5.Exit
# Enter choice (1 to 5) :  1
# Enter the First number : 56
# You entered First number: 56
# Enter the Second number : 73
# You entered Second number: 73
# The result of Addition is: 129
# ------------------------------------------------
# Select Operation
# 1.Addition
# 2.Subtraction
# 3.Multiplication
# 4.Divison
# 5.Exit
# Enter choice (1 to 5) :  5
# Exiting the calculator
